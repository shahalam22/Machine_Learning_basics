# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('CustomerPurchase.csv')

# %%
df.sample(4)
# Out:
#     Customer ID  Age  Gender Education   Review Purchased
# 38         1059   45  Female    School     Good        No
# 36         1057   34  Female        UG     Good       Yes
# 19         1040   97    Male        PG     Poor       Yes
# 4          1025   16  Female        UG  Average        No

# %%
# ekhane Age Numerical data, Gender er kono order nai tai eta Nominal data, Education ar Review er ordar ache tai era ordinal data, Purchased hocche amader outpu tai ekhane amar label encoding korbo

# %%
df = df.iloc[:,3:]

# %%
df
# Out:
#    Education   Review Purchased
# 0     School  Average        No
# 1         UG     Poor        No
# 2         PG     Good        No
# 3         PG     Good        No
# 4         UG  Average        No
# 5     School  Average       Yes
# 6     School     Good        No
# 7     School     Poor       Yes
# 8         UG  Average        No
# 9         UG     Good       Yes
# 10        UG     Good       Yes
# 11        UG     Good       Yes
# 12    School     Poor        No
# 13    School  Average        No
# 14        PG     Poor       Yes
# 15        UG     Poor        No
# 16        UG     Poor       Yes
# 17        UG     Poor       Yes
# 18    School     Good        No
# 19        PG     Poor       Yes
# 20    School  Average       Yes
# 21        PG  Average        No
# 22        PG     Poor       Yes
# 23    School     Good        No
# 24        PG  Average       Yes
# 25    School     Good        No
# 26        PG     Poor        No
# 27        PG     Poor        No
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df.iloc[:,0:2],df.iloc[:,-1],test_size=0.2)

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe = OrdinalEncoder(categories=[['School','UG','PG'],['Poor','Average','Good']])

# %%
oe.fit(x_train)
# Out:
# OrdinalEncoder(categories=[['School', 'UG', 'PG'], ['Poor', 'Average', 'Good']])

# %%
x_train = oe.transform(x_train)
# x_test = oe.transform(x_test)

# %%
x_train
# Out:
# array([[1., 0.],
#        [0., 1.],
#        [2., 0.],
#        [0., 2.],
#        [1., 2.],
#        [0., 2.],
#        [1., 1.],
#        [2., 2.],
#        [1., 0.],
#        [0., 0.],
#        [2., 0.],
#        [1., 1.],
#        [0., 1.],
#        [1., 2.],
#        [1., 1.],
#        [1., 1.],
#        [1., 2.],
#        [2., 2.],
#        [2., 0.],
#        [1., 1.],
#        [1., 2.],
#        [0., 2.],
#        [2., 1.],
#        [2., 2.],
#        [0., 2.],
#        [0., 0.],
#        [0., 0.],
#        [1., 0.],
#        [2., 1.],
#        [2., 0.],
#        [2., 0.],
#        [2., 0.],
#        [2., 1.],
#        [1., 1.],
#        [2., 0.],
#        [2., 2.],
#        [2., 0.],
#        [0., 0.],
#        [1., 0.],
#        [0., 1.]])

# %%
oe.categories_
# Out:
# [array(['School', 'UG', 'PG'], dtype=object),
#  array(['Poor', 'Average', 'Good'], dtype=object)]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
y_train = le.fit(y_train)

# %%
le.classes_

# %%
y_train
# Out:
# LabelEncoder()
