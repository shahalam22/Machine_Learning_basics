# %%
import numpy as np
import pandas as pd

df = pd.read_csv("boston_house_prices.csv")
df.columns = df.iloc[0,:]
df = df.drop(0,axis=0)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
x_boston = df.iloc[:,0:13]
y_boston = df.iloc[:,-1]

x_train,x_test,y_train,y_test = train_test_split(x_boston,y_boston,train_size=0.80,test_size=0.20,random_state=223)

# %%
lr = LinearRegression()
dt = DecisionTreeRegressor()
knn = KNeighborsRegressor()

# %%
lr.fit(x_train,y_train)
dt.fit(x_train,y_train)
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred1 = lr.predict(x_test)
y_pred2 = dt.predict(x_test)
y_pred3 = knn.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 3
#       1 y_pred1 = lr.predict(x_test)
#       2 y_pred2 = dt.predict(x_test)
# ----> 3 y_pred3 = knn.predict(x_test)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neighbors\_regression.py:258, in KNeighborsRegressor.predict(self, X)
#     255     _y = _y.reshape((-1, 1))
#     257 if weights is None:
# --> 258     y_pred = np.mean(_y[neigh_ind], axis=1)
#     259 else:
#     260     y_pred = np.empty((neigh_dist.shape[0], _y.shape[1]), dtype=np.float64)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\fromnumeric.py:3504, in mean(a, axis, dtype, out, keepdims, where)
#    3501     else:
#    3502         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3504 return _methods._mean(a, axis=axis, dtype=dtype,
# ...

# %%
print("R2 score for LR",r2_score(y_test,y_pred1))
print("R2 score for DT",r2_score(y_test,y_pred2))
print("R2 score for KNN",r2_score(y_test,y_pred3))
# Out:
# R2 score for LR 0.6618092745761723
# R2 score for DT 0.8801876382212823
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 print("R2 score for LR",r2_score(y_test,y_pred1))
#       2 print("R2 score for DT",r2_score(y_test,y_pred2))
# ----> 3 print("R2 score for KNN",r2_score(y_test,y_pred3))
#
# NameError: name 'y_pred3' is not defined

# %%
from sklearn.ensemble import BaggingRegressor

beg_regressor = BaggingRegressor(random_state=1)
beg_regressor.fit(x_train,y_train)
# Out:
# BaggingRegressor(random_state=1)

# %%
y_preds = beg_regressor.predict(x_test)

print("Training Coefficient of R2: %.3f"%beg_regressor.score(x_train,y_train))
print("Test Coefficient of R2: %.3f"%beg_regressor.score(x_test,y_test))
# Out:
# Training Coefficient of R2: 0.978
# Test Coefficient of R2: 0.849

# %% [markdown]
# ## Best parameter finding

# %%
n_samples = df.shape[0]
n_features = df.shape[1]

params = {
    'base_estimator':[None,LinearRegression(),KNeighborsRegressor()],
    'n_estimators':[20,50,100],
    'max_samples':[0.5,1.0],
    'max_features':[0.5,1.0],
    'bootstrap':[True,False],
    'bootstrap_features':[True,False]
}

bagging_regressor_grid = GridSearchCV(BaggingRegressor(random_state=1, n_jobs=-1),param_grid=params,cv=3,n_jobs=-1,verbose=1)
bagging_regressor_grid.fit(x_train,y_train)

print("Train R2 score : %.3f"%bagging_regressor_grid.best_estimator_.score(x_train,y_train))
print("Test R2 score : %.3f"%bagging_regressor_grid.best_estimator_.score(x_test,y_test))
print("Best R2 score through Grid Search : %.3f".bagging_regressor_grid.best_score_)
print("Best Parametes : ",bagging_regressor_grid.best_params_)
# Out:
# Fitting 3 folds for each of 144 candidates, totalling 432 fits
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\externals\loky\process_executor.py", line 463, in _process_worker
#     r = call_item()
#         ^^^^^^^^^^^
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\externals\loky\process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\parallel.py", line 598, in __call__
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
# ...
