# %% [markdown]
# ## Regression Tree

# %%
import pandas as pd
from pandas_datareader import data
import numpy as np
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import r2_score
# from sklearn.datasets import load_boston
from sklearn.model_selection import GridSearchCV

# %%
df = pd.read_csv("boston_house_prices.csv")
df.columns = df.iloc[0,:]
df = df.drop(0,axis=0)

# %%
df.head()
# Out:
# 0     CRIM  ZN INDUS CHAS    NOX     RM   AGE     DIS RAD  TAX PTRATIO  \
# 1  0.00632  18  2.31    0  0.538  6.575  65.2    4.09   1  296    15.3
# 2  0.02731   0  7.07    0  0.469  6.421  78.9  4.9671   2  242    17.8
# 3  0.02729   0  7.07    0  0.469  7.185  61.1  4.9671   2  242    17.8
# 4  0.03237   0  2.18    0  0.458  6.998  45.8  6.0622   3  222    18.7
# 5  0.06905   0  2.18    0  0.458  7.147  54.2  6.0622   3  222    18.7
#
# 0       B LSTAT  MEDV
# 1   396.9  4.98    24
# 2   396.9  9.14  21.6
# 3  392.83  4.03  34.7
# 4  394.63  2.94  33.4
# 5   396.9  5.33  36.2

# %%
x = df.iloc[:,0:13]
y = df.iloc[:,13]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
rt = DecisionTreeRegressor(criterion = 'friedman_mse',max_depth=5)

# %%
rt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='friedman_mse', max_depth=5)

# %%
y_pred = rt.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7224163455290411

# %% [markdown]
# ### Hyper-parameter Tuning

# %%
param_grid = {
    'max_depth':[2,4,8,10,None],
    'criterion':['friedman_mse'],
    'max_features':[0.25,0.5,1.0],
    'min_samples_split':[0.25,0.5,1.0]
}

# %%
reg = GridSearchCV(DecisionTreeRegressor(),param_grid=param_grid)

# %%
reg.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['friedman_mse'],
#                          'max_depth': [2, 4, 8, 10, None],
#                          'max_features': [0.25, 0.5, 1.0],
#                          'min_samples_split': [0.25, 0.5, 1.0]})

# %%
reg.best_score_
# Out:
# 0.6367515244112714

# %%
reg.best_params_
# Out:
# {'criterion': 'friedman_mse',
#  'max_depth': 10,
#  'max_features': 0.5,
#  'min_samples_split': 0.25}

# %% [markdown]
# ### Feature Importance

# %%
for importance, name in sorted(zip(rt.feature_importances_,x_train.columns),reverse=True):
    print(name, importance)
# Out:
# RM 0.6292222501550514
# LSTAT 0.2160192039291673
# DIS 0.07272221949123053
# CRIM 0.05220097413926926
# B 0.011905660139828151
# AGE 0.0061761261743661965
# NOX 0.004734999737276522
# PTRATIO 0.00439109750712822
# INDUS 0.002627468726682374
# ZN 0.0
# TAX 0.0
# RAD 0.0
# CHAS 0.0
