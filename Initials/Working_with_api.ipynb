# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
# response.json()['results']
pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
# Out:
#         id                                          title  \
# 0      278                       The Shawshank Redemption
# 1      238                                  The Godfather
# 2      240                          The Godfather Part II
# 3      424                               Schindler's List
# 4      389                                   12 Angry Men
# 5    19404                    Dilwale Dulhania Le Jayenge
# 6      129                                  Spirited Away
# 7      155                                The Dark Knight
# 8   496243                                       Parasite
# 9      497                                 The Green Mile
# 10  372058                                     Your Name.
# 11     680                                   Pulp Fiction
# 12     122  The Lord of the Rings: The Return of the King
# 13      13                                   Forrest Gump
# 14     429                 The Good, the Bad and the Ugly
# 15     769                                     GoodFellas
# 16     346                                  Seven Samurai
# 17  667257                              Impossible Things
# 18   12477                         Grave of the Fireflies
# 19     637                              Life Is Beautiful
#
#                                              overview release_date  \
# 0   Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1   Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2   In the continuing saga of the Corleone crime f...   1974-12-20
# 3   The true story of how businessman Oskar Schind...   1993-12-15
# 4   The defense and the prosecution have rested an...   1957-04-10
# 5   Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# 6   A young girl, Chihiro, becomes trapped in a st...   2001-07-20
# 7   Batman raises the stakes in his war on crime. ...   2008-07-16
# 8   All unemployed, Ki-taek's family takes peculia...   2019-05-30
# 9   A supernatural tale set on death row in a Sout...   1999-12-10
# 10  High schoolers Mitsuha and Taki are complete s...   2016-08-26
# 11  A burger-loving hit man, his philosophical par...   1994-09-10
# 12  As armies mass for a final battle that will de...   2003-12-01
# 13  A man with a low IQ has accomplished great thi...   1994-06-23
# 14  While the Civil War rages on between the Union...   1966-12-22
# 15  The true story of Henry Hill, a half-Irish, ha...   1990-09-12
# 16  A samurai answers a village's request for prot...   1954-04-26
# 17  After the death of her abusive husband, Matild...   2021-06-17
# 18  In the final months of World War II, 14-year-o...   1988-04-16
# 19  A touching story of an Italian book seller of ...   1997-12-20
#
#     popularity  vote_average  vote_count
# 0      157.803         8.700       26584
# 1      255.895         8.690       20178
# 2       86.816         8.575       12176
# 3      154.655         8.565       15581
# 4       69.071         8.544        8426
# 5       90.993         8.500        4410
# 6      115.479         8.537       16188
# 7      151.138         8.515       32334
# 8       86.892         8.507       17852
# 9      102.308         8.505       17068
# 10     108.689         8.488       11162
# 11     101.260         8.487       27462
# 12     112.693         8.481       23732
# 13     101.998         8.474       26975
# 14     133.413         8.500        8414
# 15      81.084         8.463       12606
# 16      53.086         8.461        3576
# 17      29.197         8.458         380
# 18       0.043         8.458        5345
# 19      50.249         8.451       12841

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = pd.concat([df,temp_df],ignore_index=True)
    # temp_df

# %%
df
# Out:
#           id                     title  \
# 0        278  The Shawshank Redemption
# 1        238             The Godfather
# 2        240     The Godfather Part II
# 3        424          Schindler's List
# 4        389              12 Angry Men
# ...      ...                       ...
# 8555  302150       The Hunter's Prayer
# 8556  118957                      Bait
# 8557    9292               Hudson Hawk
# 8558  193687           Z for Zachariah
# 8559   11066                 Boomerang
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     The defense and the prosecution have rested an...   1957-04-10
# ...                                                 ...          ...
# 8555  An assassin forges an unlikely partnership wit...   2017-06-08
# 8556  A freak tsunami traps shoppers at a coastal Au...   2012-09-05
# 8557  Eddie Hawkins, called Hudson Hawk has just bee...   1991-05-23
# 8558  In the wake of a nuclear war, a young woman su...   2015-08-13
# 8559  Marcus is a successful advertising executive w...   1992-06-30
#
#       popularity  vote_average  vote_count
# 0        157.803         8.700       26584
# 1        255.895         8.700       20178
# 2         86.816         8.575       12176
# 3        154.655         8.565       15581
# 4         69.071         8.543        8428
# ...          ...           ...         ...
# 8555      11.994         5.700         376
# 8556      95.893         5.664         726
# 8557      26.031         5.664         961
# 8558      28.679         5.700         909
# 8559      24.635         5.663         553
#
# [8560 rows x 7 columns]

# %%
df.to_csv('movies.csv')
