# %%
import pandas as pd
import seaborn as sns

# %%
tips = pd.read_csv('tips.csv')

# %%
tips.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 185       20.69  5.00    Male     No   Sun  Dinner     5
# 145        8.35  1.50  Female     No  Thur   Lunch     2
# 232       11.61  3.39    Male     No   Sat  Dinner     2
# 143       27.05  5.00  Female     No  Thur   Lunch     6
# 25        17.81  2.34    Male     No   Sat  Dinner     4

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 305         1197         1       1
# 255         1147         0       3
# 70           962         1       3
# 323         1215         0       1
# 382         1274         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 305  Crosby, Mrs. Edward Gifford (Catherine Elizabe...  female  64.0      1
# 255                         MacKay, Mr. George William    male   NaN      0
# 70                           Mulvihill, Miss. Bertha E  female  24.0      0
# 323                                 Rowe, Mr. Alfred G    male  33.0      0
# 382                         Risien, Mrs. Samuel (Emma)  female   NaN      0
#
#      Parch      Ticket   Fare Cabin Embarked
# 305      1      112901  26.55   B26        S
# 255      0  C.A. 42795   7.55   NaN        S
# 70       0      382653   7.75   NaN        Q
# 323      0      113790  26.55   NaN        S
# 382      0      364498  14.50   NaN        S

# %%
flights = pd.read_csv('airlines.csv')

# %%
flights.sample(5)
# Out:
#       Airline ID                                   Name Alias IATA ICAO  \
# 3929        3935                      Peninsula Airways    \N   KS  PEN
# 2444        2445                          Foster Yeoman    \N  NaN  JFY
# 844          844                               Airailes    \N  NaN  EOL
# 2369        2370  Fleet Requirements Air Direction Unit    \N  NaN  BWY
# 4235        4241                        Royal Air Force    \N   RR  RFR
#
#        Callsign         Country Active
# 3929  PENINSULA   United States      Y
# 2444     YEOMAN  United Kingdom      N
# 844        EOLE          France      N
# 2369   BROADWAY  United Kingdom      N
# 4235     RAFAIR  United Kingdom      N

# %%
iris = pd.read_csv('Iris.csv')

# %%
iris.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 22    23            4.6           3.6            1.0           0.2
# 136  137            6.3           3.4            5.6           2.4
# 138  139            6.0           3.0            4.8           1.8
# 21    22            5.1           3.7            1.5           0.4
# 33    34            5.5           4.2            1.4           0.2
#
#             Species
# 22      Iris-setosa
# 136  Iris-virginica
# 138  Iris-virginica
# 21      Iris-setosa
# 33      Iris-setosa

# %% [markdown]
# ### ScatterPlot (Numerical - Numerical)

# %%
# tips
sns.scatterplot(x=tips['total_bill'],y=tips['tip'],hue=tips['sex'],style=tips['smoker'],size=tips['size'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### Barplot (Numerical - Categorical)

# %%
# titanic.head(3)
# sns.barplot(x=titanic['Pclass'],y=titanic['Age'])
# sns.barplot(x=titanic['Pclass'],y=titanic['Fare'])
sns.barplot(x=titanic['Pclass'],y=titanic['Age'],hue=titanic['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# ### Box Plot (Numerical - Categorical)

# %%
sns.boxplot(x=titanic['Sex'],y=titanic['Age'],hue=titanic['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# ### Dist Plot (Numerical - Categorical)

# %%
# sns.distplot(titanic['Age'])
sns.distplot(titanic[titanic['Survived']==0]['Age'],hist=False)
sns.distplot(titanic[titanic['Survived']==1]['Age'],hist=False)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_15764\209147696.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic['Survived']==0]['Age'],hist=False)
# C:\Users\USER\AppData\Local\Temp\ipykernel_15764\209147696.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic['Survived']==1]['Age'],hist=False)
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ### Heat Map (Categorical - Categorical)

# %%
sns.heatmap(pd.crosstab(titanic['Pclass'],titanic['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
# titanic.groupby('Pclass').mean()['Survived']

# %% [markdown]
# ### Cluster Map (Categorical - Categorical)

# %%
sns.clustermap(pd.crosstab(titanic['SibSp'],titanic['Survived']))

# %% [markdown]
# ### Pair Plot ()

# %%
sns.pairplot(iris,hue='Species')
# iris.info()

# %% [markdown]
# ### Line Plot (Numerical - Numerical)

# %%
# flights.groupby('Name').sum()

# new = flights.groupby('year').sum().reset_index()
# sns.lineplot(new['year'],new['passengers'])

# %%
# sns.heatmap(flights.pivot_table(values='passengers',index='month',columns='year'))

# %%
# sns.clustermap(flights.pivot_table(values='passengers',index='month',columns='year'))
